# %% [markdown]
# Load Files from S3

# %%
df_customers = spark.read \
    .option("header", True) \
    .csv("s3a://capgemini-retail-etl-shiva/sftp/customers_src_07052026_120000.csv")

# Products

df_products = spark.read \
    .option("header", True) \
    .csv("s3a://capgemini-retail-etl-shiva/sftp/products_src.csv")

# Stores

df_stores = spark.read \
    .option("header", True) \
    .csv("s3a://capgemini-retail-etl-shiva/sftp/stores_src.csv")

# Sales

df_sales = spark.read \
    .option("header", True) \
    .csv("s3a://capgemini-retail-etl-shiva/sftp/sales_src.csv")

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS capgeminipro.retail_bronze;

# %%
# %sql
USE capgeminipro.retail_bronze;

# %% [markdown]
# Bronze Customers

# %%
# %sql
CREATE OR REPLACE TABLE bronze_customers
USING DELTA
AS
SELECT *
FROM read_files(
  's3://capgemini-retail-etl-shiva/sftp/customers_src_20042026100105.csv',
  format => 'csv',
  header => true
);

# %%
# %sql
CREATE OR REPLACE TABLE capgeminipro.retail_bronze.bronze_customers1
USING DELTA
AS
SELECT *
FROM read_files(
  's3://capgemini-retail-etl-shiva/raw/customers_src_30102026100105.csv',
  format => 'csv',
  header => true
)

# %%
# %sql
CREATE OR REPLACE TABLE capgeminipro.retail_bronze.bronze_customers1
USING DELTA
AS
SELECT *
FROM read_files(
  's3://capgemini-retail-etl-shiva/raw/customers_src_30102026100105.csv',
  format => 'csv',
  header => true
);

# %%
# %sql
DROP TABLE IF EXISTS bronze_products;

CREATE TABLE bronze_products
USING DELTA
AS
SELECT *
FROM read_files(
  's3://capgemini-retail-etl-shiva/sftp/products_src_20042026100105.csv',
  format => 'csv',
  header => true
);

# %%
# %sql
DROP TABLE IF EXISTS bronze_stores;

CREATE TABLE bronze_stores
USING DELTA
AS
SELECT *
FROM read_files(
  's3://capgemini-retail-etl-shiva/sftp/stores_src_20042026100107.csv',
  format => 'csv',
  header => true
);

# %%
# %sql
DROP TABLE IF EXISTS bronze_sales;

CREATE TABLE bronze_sales
USING DELTA
AS
SELECT *
FROM read_files(
  's3://capgemini-retail-etl-shiva/sftp/sales_transactions_src_20042026100107.csv',
  format => 'csv',
  header => true
);
